# %% [markdown]
# <a href="https://colab.research.google.com/github/johnnyboy1287/605hw1gif/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#There is always an issue of "ImportError: Using `low_cpu_mem_usage=True` or a `device_map` requires Accelerate: `pip install accelerate`"
#so use the command below to install accelerare from the package manager.


# !pip -qqq install bitsandbytes accelerate
# !pip install openai


import torch
from transformers import pipeline

pipe = pipeline("text-generation", model="TinyLlama/TinyLlama-1.1B-Chat-v1.0", torch_dtype=torch.bfloat16, device_map="auto")

# We use the tokenizer's chat template to format each message - see https://huggingface.co/docs/transformers/main/en/chat_templating
messages = [
    {
        "role": "system",
        "content": "You are a friendly chatbot who always responds in the style of a pirate",
    },
    {"role": "user", "content": "How many helicopters can a human eat in one sitting?"},
]
prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
outputs = pipe(prompt, max_new_tokens=256, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)
print(outputs[0]["generated_text"])
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 27.9 MB/s eta 0:00:00
# Collecting openai
#   Downloading openai-1.23.6-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.1 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.1)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.23.6
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# <|system|>
# You are a friendly chatbot who always responds in the style of a pirate</s>
# <|user|>
# How many helicopters can a human eat in one sitting?</s>
# <|assistant|>
# There is no definitive answer to this question as the number of helicopters that a human can eat in one sitting is subjective and may vary depending on various factors such as age, physical condition, and hunger. However, it is generally accepted that humans are able to eat about 10-15 pounds of food per day, which is approximately 5-7 helicopters. It's worth noting that this is just an estimate and may vary depending on the dietary preferences and habits of the person in question. It is also important to note that eating more than a single helicopter at a time can lead to a decrease in energy levels and increase the risk of obesity, among other health concerns.

# %%
messages = [
    {
        "role": "system",
        "content": "You are a friendly chatbot who always responds in the style of a math teacher",
    },
    {"role": "user", "content": "How many helicopters can a human eat in one sitting?"},
]
prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
outputs = pipe(prompt, max_new_tokens=256, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)
print(outputs[0]["generated_text"])
# Out:
# <|system|>
# You are a friendly chatbot who always responds in the style of a math teacher</s>
# <|user|>
# How many helicopters can a human eat in one sitting?</s>
# <|assistant|>
# A human can eat about 20 to 25 helicopters in one sitting, depending on the size of the helicopters and their taste preferences. The exact number of helicopters that a human can consume in one sitting is a matter of personal preference and individual body size.

# %%
# prompt: recreate the gen pirate code to have the function just called gen

def gen(user_prompt):
    # Pre-defined system message setting the style of the chatbot
    messages = [
        {"role": "system", "content": "You are a friendly chatbot who always responds in the style of a Math Teacher"},
        {"role": "user", "content": user_prompt},
    ]

    # Applying the chat template
    prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)

    # Generating the output
    outputs = pipe(prompt, max_new_tokens=256, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)

    # Returning only the generated text without the system or user prompts
    if len(outputs) > 1:
        return outputs[0]["generated_text"].split("User: ")[1].strip()
    else:
        return outputs[0]["generated_text"]

# Example usage
user_input = "How many helicopters can a human eat in one sitting?"
print(gen(user_input))
# Out:
# <|system|>
# You are a friendly chatbot who always responds in the style of a Math Teacher</s>
# <|user|>
# How many helicopters can a human eat in one sitting?</s>
# <|assistant|>
# There is no definitive answer to this question as the number of helicopters a human can eat in one sitting depends on a variety of factors such as the individual's appetite, physical condition, and nutritional needs. However, studies have shown that people can eat around 25-30 helicopters in one sitting, with some individuals consuming up to 40 helicopters. However, the exact number of helicopters an individual can eat in one sitting may vary depending on factors such as the size of the helicopter, its composition, and the individual's body weight and activity level.

# %%
# Clone the repository
# !git clone https://github.com/openai/grade-school-math.git

# Check size of the cloned repository
# !du -sh grade-school-math

# Check available disk space
# !df -h
# Out:
# Cloning into 'grade-school-math'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 36 (delta 11), reused 7 (delta 7), pack-reused 14
# Receiving objects: 100% (36/36), 3.13 MiB | 9.34 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# 18M	grade-school-math
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         202G   32G  170G  16% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G  4.0K  5.7G   1% /dev/shm
# /dev/root       2.0G  1.1G  849M  57% /usr/sbin/docker-init
# tmpfs           6.4G  372K  6.4G   1% /var/colab
# /dev/sda1       242G   83G  160G  35% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
# %cd grade-school-math
# Out:
# /content/grade-school-math

# %%
gen("what are the theorys?")
# Out:
# '<|system|>\nYou are a friendly chatbot who always responds in the style of a Math Teacher</s>\n<|user|>\nwhat are the theorys?</s>\n<|assistant|>\nSure! Here are some of the major theories in mathematical logic:\n\n1. Peano Axioms: These are a set of axioms that provide a foundation for the study of mathematical logic. They are derived from the idea that every valid proof of a statement has a finite number of steps and is constructed using only finite numbers of symbols.\n\n2. Modal Logic: This is a branch of mathematics that deals with questions of possibility and necessity. It is based on the idea that a statement is true iff it is true with a certain set of possible worlds.\n\n3. Modal Realism: This is a philosophical theory that proposes that the world is real and that it is possible for things to be true or false. Modal Realism is based on the idea that mathematical statements are true or false, not just true or false in the sense of being a logical conclusion.\n\n4. Foundations: This is the area of mathematics that studies the structure of the logical system. It includes topics such as axiomatic systems, axiomatic set theory, and the axiom of choice.\n\n5. Computability: This is a theory in computer science that deals with the question of whether'

# %%
import openai


openai.api_key = "sk-proj-xhEwz7soOEY7J3UVwYJgT3BlbkFJE2bCvJttjZgqMigbU8vQ"



def ask_gpt(prompt, model="gpt-3.5-turbo", max_tokens=100):
    try:
        response = openai.Completion.create(
            engine=model,
            prompt=prompt,
            max_tokens=max_tokens,
            temperature=0.7
        )
        return response.choices[0].text.strip()
    except Exception as e:
        return str(e)

# Example usage
prompt_text = "What is the future of artificial intelligence?"
response_text = ask_gpt(prompt_text)
print(response_text)
# Out:
# You tried to access openai.Completion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
